# %%
from visualizer import TokenPredictor, create_token_graph, visualize_prediction

message = " "
model_name = " "

predictor = TokenPredictor(model_name)
predictions = predictor.predict_tokens(message)
G = create_token_graph(model_name, predcitions)
plt = visualize_predict(G)
plt.show()
